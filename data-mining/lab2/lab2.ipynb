# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ

# %% [markdown]
# #### Факультет физико-математических и естественных наук
# #### Кафедра математического моделирования и искусственного интеллекта

# %% [markdown]
# ## ОТЧЕТ ПО ЛАБОРАТОРНОЙ РАБОТЕ № 2

# %% [markdown]
# #### Дисциплина: Интеллектуальный анализ данных

# %% [markdown]
# ##### Студент: Матюхин Григорий Васильевич
# ##### Группа: НПИбд-01-21

# %% [markdown]
# ## Москва 2024
# ***

# %% [markdown]
# ### Вариант №11
#
# - Алгоритм: FPMax
# - День недели (поле order_dow таблицы orders): “4”
# - Код департамента (поле department_id таблицы products): “5”
# - Запрос: определить час дня, в который было совершено более всего покупок (заказов)
# - Показатель оценки ассоциативных правил: рычаг (leverage)

# %% [markdown]
# # Выполнение

# %%
TARGET_ORDER_DOW = 4
TARGET_DEPARTMENT_ID = 5

# %% [markdown]
# ## 1. Открыть базу данных

# %%
import sqlite3
db = sqlite3.connect("instacart.db")

# %%
c = db.cursor()
c.execute("SELECT name FROM sqlite_master")
c.fetchall()
# Out:
# [('aisles',),
#  ('products',),
#  ('departments',),
#  ('orders',),
#  ('order_products__train',)]

# %% [markdown]
# ## 2. Загрузить данные в датафрейм

# %%
import pandas

# %%
dpts = pandas.read_sql("SELECT * FROM departments", db)
dpts.head()
# Out:
#   department_id department
# 0             1     frozen
# 1             2      other
# 2             3     bakery
# 3             4    produce
# 4             5    alcohol

# %%
dpts.set_index("department_id", inplace=True)

# %%
prod = pandas.read_sql("SELECT * FROM products", db)
prod.head()
# Out:
#   product_id                                       product_name aisle_id  \
# 0          1                         Chocolate Sandwich Cookies       61
# 1          2                                   All-Seasons Salt      104
# 2          3               Robust Golden Unsweetened Oolong Tea       94
# 3          4  Smart Ones Classic Favorites Mini Rigatoni Wit...       38
# 4          5                          Green Chile Anytime Sauce        5
#
#   department_id
# 0            19
# 1            13
# 2             7
# 3             1
# 4            13

# %%
prod.set_index("product_id", inplace=True)

# %%
ords = pandas.read_sql("SELECT * FROM orders", db)
ords.head()
# Out:
#   order_id user_id eval_set order_number order_dow order_hour_of_day  \
# 0  2539329       1    prior            1         2                08
# 1  2398795       1    prior            2         3                07
# 2   473747       1    prior            3         3                12
# 3  2254736       1    prior            4         4                07
# 4   431534       1    prior            5         4                15
#
#   days_since_prior_order
# 0
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %%
ords.set_index("order_id", inplace=True)

# %%
orders = pandas.read_sql(
    "SELECT op.*, o.order_hour_of_day FROM order_products__train op JOIN orders o ON op.order_id = o.order_id JOIN products p ON op.product_id = p.product_id WHERE o.order_dow=? AND p.department_id=?",
    db,
    params=(TARGET_ORDER_DOW, TARGET_DEPARTMENT_ID))
orders.head()
# Out:
#   order_id product_id add_to_cart_order reordered order_hour_of_day
# 0   877974       1808                 1         0                11
# 1  1859940      15511                 1         1                17
# 2  3409264       2120                 3         1                08
# 3  1881604      10607                 6         1                12
# 4  1881604      29509                 2         1                12

# %%
print("Total rows:", len(orders))
print("Transactions:", len(orders.order_id.unique()))
print("Products:", len(orders.product_id.unique()))
# Out:
# Total rows: 958
# Transactions: 455
# Products: 314

# %% [markdown]
# ## 3. Определить час дня, в который было совершено более всего покупок (заказов)

# %%
orders.groupby("order_hour_of_day").size().idxmax()
# Out:
# '15'

# %% [markdown]
# ## 4. Транзакционная база данных

# %%
xacts = (orders
        .merge(prod, left_on='product_id', right_index=True)
        .drop('product_id', axis=1)
        .groupby('order_id')['product_name']
        .apply(list)
    )
xacts
# Out:
# order_id
# 1007120    [Prosecco, 12 Oz Lager, Ksa Ko?Lsch Style Ale,...
# 1007997    [Pinot Noir, Sauvignon Blanc, Cabernet Sauvign...
# 1009684                                    [Pinot Noir Wine]
# 1009730                                     [Tequila Silver]
# 1014150                                    [Sauvignon Blanc]
#                                  ...
# 972664     [Woodbridge Cabernet Sauvignon, 80  Vodka Holi...
# 979819                         [Pinot Noir, Chardonnay Wine]
# 983217                                  [Cabernet Sauvignon]
# 990839                              [London Dry Gin England]
# 997158                                    [Ultra Light Beer]
# Name: product_name, Length: 455, dtype: object

# %%
max_items_xact = xacts.apply(len).idxmax()
max_items_xact
# Out:
# '2253479'

# %%
list(xacts[max_items_xact])
# Out:
# ['Westfalia Red Ale',
#  "Little Sumpin' Sumpin' Ale",
#  'Belgium Beer',
#  'Mighty Dry Hard Cider',
#  'Belgian White Wheat Ale',
#  'Crisp Hard Cider Crisp Apple',
#  'Cabernet Sauvignon',
#  'Scrimshaw Pilsner Style Beer',
#  'Merlot',
#  'Day Time Fractional IPA',
#  '90 Minute Imperial Ipa',
#  'Red Wine, Dark, California, 2013',
#  'Villager Ipa']

# %% [markdown]
# ## 5. Бинарная транзакционная база данных

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_fit = te.fit(xacts).transform(xacts)
te_fit
# Out:
# array([[ True,  True, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
binary_df = pandas.DataFrame(te_fit, columns=te.columns_)
binary_df
# Out:
#      12 Oz Beer  12 Oz Lager  12 Year Old Single Malt Scotch Speyside   1664  \
# 0          True         True                                    False  False
# 1         False        False                                    False  False
# 2         False        False                                    False  False
# 3         False        False                                    False  False
# 4         False        False                                    False  False
# ..          ...          ...                                      ...    ...
# 450       False        False                                    False  False
# 451       False        False                                    False  False
# 452       False        False                                    False  False
# 453       False        False                                    False  False
# 454       False        False                                    False  False
#
#      312 Urban Wheat  312 Urban Wheat Ale  \
# 0              False                False
# 1              False                False
# 2              False                False
# 3              False                False
# 4              False                False
# ..               ...                  ...
# 450            False                False
# 451            False                False
# 452            False                False
# 453            False                False
# 454            False                False
#
#      46 / 94 Proof Bourbon Kentucky Whiskey  60 Minute IPA  \
# 0                                     False          False
# 1                                     False          False
# 2                                     False          False
# 3                                     False          False
# 4                                     False          False
# ..                                      ...            ...
# 450                                   False          False
# 451                                   False          False
# 452                                   False          False
# 453                                   False          False
# 454                                   False          False
#
#      80  Vodka Holiday Edition    805  ...  Viognier  Vodka  Vodka 525  \
# 0                        False  False  ...     False  False      False
# 1                        False  False  ...     False  False      False
# 2                        False  False  ...     False  False      False
# 3                        False  False  ...     False  False      False
# 4                        False  False  ...     False  False      False
# ..                         ...    ...  ...       ...    ...        ...
# 450                       True  False  ...     False  False      False
# 451                      False  False  ...     False  False      False
# 452                      False  False  ...     False  False      False
# 453                      False  False  ...     False  False      False
# 454                      False  False  ...     False  False      False
#
#      Washington State Merlot  Westfalia Red Ale  Whiskey  \
# 0                      False              False    False
# 1                      False              False    False
# 2                      False              False    False
# 3                      False              False    False
# 4                      False              False    False
# ..                       ...                ...      ...
# 450                    False              False    False
# 451                    False              False    False
# 452                    False              False    False
# 453                    False              False    False
# 454                    False              False    False
#
#      White Label Blended Scotch Whisky  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ..                                 ...
# 450                              False
# 451                              False
# 452                              False
# 453                              False
# 454                              False
#
#      White Wine Winemaker's Blend California, 2010  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ..                                             ...
# 450                                          False
# 451                                          False
# 452                                          False
# 453                                          False
# 454                                          False
#
#      Woodbridge Cabernet Sauvignon  Zinfandel
# 0                            False      False
# 1                            False      False
# 2                            False      False
# 3                            False      False
# 4                            False      False
# ..                             ...        ...
# 450                           True      False
# 451                          False      False
# 452                          False      False
# 453                          False      False
# 454                          False      False
#
# [455 rows x 314 columns]

# %%
product_counts = binary_df.sum().sort_values(ascending=False)
top_products = product_counts.head(3)
print(f"Top products: \n{top_products}")
# Out:
# Top products:
# Beer                  45
# Cabernet Sauvignon    43
# Sauvignon Blanc       38
# dtype: int64

# %% [markdown]
# ## 6. Поиск популярных наборов

# %%
from mlxtend.frequent_patterns import fpmax

absolute_min_support = 3
relative_min_support = absolute_min_support / len(binary_df)

frequent_itemsets = fpmax(binary_df, min_support=relative_min_support, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support                   itemsets
# 0  0.006593              (12 Oz Lager)
# 1  0.006593      (312 Urban Wheat Ale)
# 2  0.006593   (90 Minute Imperial Ipa)
# 3  0.006593               (Ale, Amber)
# 4  0.006593  (Alto Adige Pinot Grigio)

# %%
max_len = frequent_itemsets.itemsets.apply(len).max()
max_len
# Out:
# np.int64(2)

# %%
frequent_itemsets[frequent_itemsets.itemsets.apply(lambda x: len(x) == max_len)]
# Out:
#       support                                           itemsets
# 9    0.006593  (Cabernet Sauvignon, Cabernet Sauvignon Sonoma...
# 47   0.006593             (Beer, Mixed 12 Pack Lion's Share Ale)
# 52   0.006593                       (Tequila Silver, Chardonnay)
# 55   0.006593  (Little Sumpin' Sumpin' Ale, Longboard Island ...
# 57   0.006593                (IPA, Crisp Hard Cider Crisp Apple)
# 60   0.006593                 (Frontier Whiskey, India Pale Ale)
# 61   0.008791                       (Cabernet Sauvignon, Merlot)
# 62   0.006593             (Sauvignon Blanc, California Red Wine)
# 64   0.006593            (India Pale Ale, Premium Belgian Lager)
# 67   0.006593      (Cabernet Sauvignon, Variety Pack Hard Cider)
# 68   0.010989          (Variety Pack Hard Cider, India Pale Ale)
# 69   0.006593               (Crisp Hard Cider Crisp Apple, Beer)
# 72   0.008791               (India Pale Ale, Extra Beer Bottles)
# 73   0.006593                               (Beer, Belgium Beer)
# 74   0.008791                        (Amber Ale, India Pale Ale)
# 75   0.008791                                  (Amber Ale, Beer)
# 77   0.006593              (Cabernet Sauvignon, Pinot Noir Wine)
# 78   0.006593                  (India Pale Ale, Pinot Noir Wine)
# 79   0.006593       (Little Sumpin' Sumpin' Ale, India Pale Ale)
# 80   0.008791   (Cabernet Sauvignon, Little Sumpin' Sumpin' Ale)
# 81   0.006593                                      (Clara, Beer)
# 82   0.006593                            (Clara, India Pale Ale)
# 83   0.006593      (Cabernet Sauvignon, Belgian White Wheat Ale)
# 84   0.010989                    (Belgian White Wheat Ale, Beer)
# 85   0.006593                      (Pinot Noir, Chardonnay Wine)
# 87   0.006593                         (Beer, Premium Lager Beer)
# 88   0.013187               (India Pale Ale, Premium Lager Beer)
# 89   0.006593      (Cabernet Sauvignon, Prosecco Sparkling Wine)
# 90   0.006593         (Prosecco Sparkling Wine, Sauvignon Blanc)
# 91   0.006593          (India Pale Ale, Prosecco Sparkling Wine)
# 92   0.013187                   (Cabernet Sauvignon, Pinot Noir)
# 94   0.006593               (Cabernet Sauvignon, India Pale Ale)
# 95   0.021978                             (India Pale Ale, Beer)
# 96   0.006593                                 (Beer, Chardonnay)
# 97   0.006593                      (Chardonnay, Sauvignon Blanc)
# 98   0.017582                   (Cabernet Sauvignon, Chardonnay)
# 99   0.015385              (Cabernet Sauvignon, Sauvignon Blanc)
# 100  0.006593                         (Cabernet Sauvignon, Beer)

# %% [markdown]
# ## 7. Ассоциативные правила

# %% [markdown]
# Использование `fpmax` на предудущем шаге, а также выбор только элементов длинной два ломают постороение ассоциативных правил.
# Такое поведение `fpmax` уже было замечено, но не исправлено https://github.com/rasbt/mlxtend/issues/1030, поэтому создадим наши популярные наборы заново используя `fpgrowth`.
#
# Также в задании не задан порог уверенности, поэтому выберем его случайно.

# %%
import random
min_conf = random.random()
min_conf
# Out:
# 0.206053025202655

# %%
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth

frequent_itemsets = fpgrowth(binary_df, min_support=relative_min_support, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_conf)
rules
# Out:
#                            antecedents                     consequents  \
# 0                         (Pinot Noir)            (Cabernet Sauvignon)
# 1                    (Pinot Noir Wine)                (India Pale Ale)
# 2                    (Pinot Noir Wine)            (Cabernet Sauvignon)
# 3                     (Tequila Silver)                    (Chardonnay)
# 4            (Belgian White Wheat Ale)                          (Beer)
# 5            (Belgian White Wheat Ale)            (Cabernet Sauvignon)
# 6         (Little Sumpin' Sumpin' Ale)                (India Pale Ale)
# 7         (Little Sumpin' Sumpin' Ale)            (Cabernet Sauvignon)
# 8                         (Chardonnay)            (Cabernet Sauvignon)
# 9                 (Extra Beer Bottles)                (India Pale Ale)
# 10                (Premium Lager Beer)                (India Pale Ale)
# 11                    (India Pale Ale)                          (Beer)
# 12                              (Beer)                (India Pale Ale)
# 13                         (Amber Ale)                (India Pale Ale)
# 14                         (Amber Ale)                          (Beer)
# 15               (California Red Wine)               (Sauvignon Blanc)
# 16                      (Belgium Beer)                          (Beer)
# 17    (Mixed 12 Pack Lion's Share Ale)                          (Beer)
# 18           (Variety Pack Hard Cider)            (Cabernet Sauvignon)
# 19           (Variety Pack Hard Cider)                (India Pale Ale)
# 20                            (Merlot)            (Cabernet Sauvignon)
# 21                               (IPA)  (Crisp Hard Cider Crisp Apple)
# 22      (Crisp Hard Cider Crisp Apple)                           (IPA)
# 23      (Crisp Hard Cider Crisp Apple)                          (Beer)
# 24             (Premium Belgian Lager)                (India Pale Ale)
# 25        (Little Sumpin' Sumpin' Ale)        (Longboard Island Lager)
# 26            (Longboard Island Lager)    (Little Sumpin' Sumpin' Ale)
# 27  (Cabernet Sauvignon Sonoma County)            (Cabernet Sauvignon)
# 28                   (Chardonnay Wine)                    (Pinot Noir)
# 29                             (Clara)                          (Beer)
# 30                             (Clara)                (India Pale Ale)
# 31                  (Frontier Whiskey)                (India Pale Ale)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.048352            0.094505  0.013187    0.272727   2.885835
# 1             0.021978            0.068132  0.006593    0.300000   4.403226
# 2             0.021978            0.094505  0.006593    0.300000   3.174419
# 3             0.010989            0.079121  0.006593    0.600000   7.583333
# 4             0.024176            0.098901  0.010989    0.454545   4.595960
# 5             0.024176            0.094505  0.006593    0.272727   2.885835
# 6             0.021978            0.068132  0.006593    0.300000   4.403226
# 7             0.021978            0.094505  0.008791    0.400000   4.232558
# 8             0.079121            0.094505  0.017582    0.222222   2.351421
# 9             0.019780            0.068132  0.008791    0.444444   6.523297
# 10            0.035165            0.068132  0.013187    0.375000   5.504032
# 11            0.068132            0.098901  0.021978    0.322581   3.261649
# 12            0.098901            0.068132  0.021978    0.222222   3.261649
# 13            0.019780            0.068132  0.008791    0.444444   6.523297
# 14            0.019780            0.098901  0.008791    0.444444   4.493827
# 15            0.015385            0.083516  0.006593    0.428571   5.131579
# 16            0.019780            0.098901  0.006593    0.333333   3.370370
# 17            0.010989            0.098901  0.006593    0.600000   6.066667
# 18            0.017582            0.094505  0.006593    0.375000   3.968023
# 19            0.017582            0.068132  0.010989    0.625000   9.173387
# 20            0.015385            0.094505  0.008791    0.571429   6.046512
# 21            0.013187            0.017582  0.006593    0.500000  28.437500
# 22            0.017582            0.013187  0.006593    0.375000  28.437500
# 23            0.017582            0.098901  0.006593    0.375000   3.791667
# 24            0.015385            0.068132  0.006593    0.428571   6.290323
# 25            0.021978            0.013187  0.006593    0.300000  22.750000
# 26            0.013187            0.021978  0.006593    0.500000  22.750000
# 27            0.006593            0.094505  0.006593    1.000000  10.581395
# 28            0.026374            0.048352  0.006593    0.250000   5.170455
# 29            0.024176            0.098901  0.006593    0.272727   2.757576
# 30            0.024176            0.068132  0.006593    0.272727   4.002933
# 31            0.013187            0.068132  0.006593    0.500000   7.338710
#
#     leverage  conviction  zhangs_metric
# 0   0.008617    1.245055       0.686682
# 1   0.005096    1.331240       0.790262
# 2   0.004516    1.293564       0.700375
# 3   0.005724    2.302198       0.877778
# 4   0.008598    1.652015       0.801802
# 5   0.004309    1.245055       0.669670
# 6   0.005096    1.331240       0.790262
# 7   0.006714    1.509158       0.780899
# 8   0.010105    1.164207       0.624105
# 9   0.007444    1.677363       0.863789
# 10  0.010791    1.490989       0.848140
# 11  0.015240    1.330194       0.744104
# 12  0.015240    1.198116       0.769512
# 13  0.007444    1.677363       0.863789
# 14  0.006835    1.621978       0.793161
# 15  0.005309    1.603846       0.817708
# 16  0.004637    1.351648       0.717489
# 17  0.005507    2.252747       0.844444
# 18  0.004932    1.448791       0.761372
# 19  0.009791    2.484982       0.906935
# 20  0.007337    2.112821       0.847656
# 21  0.006362    1.964835       0.977728
# 22  0.006362    1.578901       0.982103
# 23  0.004854    1.441758       0.749441
# 24  0.005545    1.630769       0.854167
# 25  0.006304    1.409733       0.977528
# 26  0.006304    1.956044       0.968820
# 27  0.005970         inf       0.911504
# 28  0.005318    1.268864       0.828442
# 29  0.004202    1.239011       0.653153
# 30  0.004946    1.281319       0.768769
# 31  0.005695    1.863736       0.875278

# %% [markdown]
# ## 8. Поиск лучшего ассоциативного правила по заданной метрике

# %%
rules.sort_values("leverage", ascending=False).head(1)
# Out:
#    antecedents       consequents  antecedent support  consequent support  \
# 12      (Beer)  (India Pale Ale)            0.098901            0.068132
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 12  0.021978    0.222222  3.261649   0.01524    1.198116       0.769512
